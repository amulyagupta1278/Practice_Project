# %% [markdown]
# <a href="https://colab.research.google.com/github/amulyagupta1278/Coding-Projects/blob/Deep-Learning/Convolution%20NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Computer Vision

# %%
import torch
import torchvision
from torch import nn
import torch.nn.functional as F

# %% [markdown]
# Downloading Dataset

# %%
mnist_train_images = torchvision.datasets.MNIST(root='', download = True, train=True, transform=torchvision.transforms.ToTensor())
mnist_valid_images = torchvision.datasets.MNIST(root='', download = True, train=False, transform=torchvision.transforms.ToTensor())
len(mnist_train_images), len(mnist_valid_images)


# mnist_train_images.__len__ = lambda : "hello"
# Out:
# (60000, 10000)

# %%
len(mnist_train_images)
# Out:
# 60000

# %% [markdown]
# Dataset has to be converted to dataloaders

# %%
from torch.utils.data import DataLoader

train_dl = DataLoader(mnist_train_images, batch_size=16)
valid_dl = DataLoader(mnist_valid_images, batch_size=32)

# %%
x,y=next(iter(train_dl))
x.shape
# Out:
# torch.Size([16, 1, 28, 28])

# %% [markdown]
# ## Creating our model
#
# Convolutional Neural Network

# %% [markdown]
# # Convolutional Neural
#
# Read about Padding and Strides in CNNs
#
#
# Strides are used to save computation
#
# Padding is done to retain information within the image

# %%
class Lambda(nn.Module):
    def __init__(self, func):
        super().__init__()
        self.func=func
    
    def forward(self,x): return self.func(x)
    def __repr__(self): return f"Lambda({str(self.func).split()[1]})"

def flatten(x): return x.view(x.shape[0],-1) #16,1,28,28 -> (16,1x28x28)
def mnist_preprocess(x): 
    x= x.view(-1,1,28,28) 
    x = F.normalize(x)
    return x


def get_cnn_model(num_classes=10): #helper function which returns the model class
    assert type(num_classes)==int
    layers=[Lambda(mnist_preprocess), 
            nn.Conv2d(1,8,5,stride=2,padding = 2), #input = 16x1x28x28, output = 16x8x28x28
            nn.ReLU(),
            nn.Conv2d(8,16,kernel_size=3,stride=2,padding=1), # #output = 16x16x28x28
            nn.ReLU(),
            nn.Conv2d(16,32,3,2,1), #output 16x32x_x_
            nn.ReLU(),
            nn.Conv2d(32,32,3,2,1), #output  16 x 32 x H x W
            nn.ReLU(),
            nn.AdaptiveAvgPool2d(1), # output 16x32x1x1
            Lambda(flatten),    #output 16x32
            nn.Linear(32,num_classes) #output = 16x10
            ]
    return nn.Sequential(*layers)

#nn.Sequential is basically a class given by PyTorch, exactly the same the model we built before
# we had to 
# initialize the super().__init__
# declare each layer as a module
# define an explicit forward function
#take care of how GPU operations will work

# %%
model = get_cnn_model(10)
model
# Out:
# Sequential(
#   (0): Lambda(mnist_preprocess)
#   (1): Conv2d(1, 8, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (2): ReLU()
#   (3): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (4): ReLU()
#   (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (6): ReLU()
#   (7): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (8): ReLU()
#   (9): AdaptiveAvgPool2d(output_size=1)
#   (10): Lambda(flatten)
#   (11): Linear(in_features=32, out_features=10, bias=True)
# )

# %%
x,y=next(iter(train_dl))
x.shape, model(x).shape
# Out:
# (torch.Size([16, 1, 28, 28]), torch.Size([16, 10]))

# %% [markdown]
# Model construction is done, now we define loss function
#
#
# Homework - understand the working of this loss function

# %%
def logsumexp(x):
  m=x.max(-1,keepdim=True).values
  return m+ (x-m).exp().sum(-1,keepdim=True)
def log_softmax(x): return x -logsumexp(x)
def nll(pred,target):
  log_sm_pred=log_softmax(pred)
  return -log_sm_pred[range(log_sm_pred.shape[0]),target].mean()

# %% [markdown]
# Optimizer

# %%
class optimizer():
  def __init__(self, params, lr=0.1): self.params, self.lr = list(params), lr
  def step(self):
    with torch.no_grad():
      for p in self.params: 
          p-=self.lr*p.grad

  def zero_grad(self):
    for p in self.params: p.grad.data.zero_()

# %%
def accuracy(pred,targ): return (torch.argmax(pred,dim=1)==targ).float().mean()

# %% [markdown]
# Extra note: To run the model on GPU,
#
# 1. Put x,y on GPU
# 2. Put model on GPU
#
#
# x = x.cuda()
#
# y=y.cuda()
#
# model = model.cuda()

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# Learner function

# %%
# def mnist_preprocess(x):
#     x= x.view(-1,1,28,28) 
#     x = F.normalize(x)
#     return x

class Learner():
    def __init__(self, train_dl, valid_dl,model=get_cnn_model(), optimizer=None):
        self.train_dl = train_dl
        self.valid_dl = valid_dl
        self.model = model
        if torch.cuda.is_available(): self.model = self.model.cuda()
        self.opt = optimizer(self.model.parameters) if not optimizer else optimizer #show working with another optimizer

    def fit(self, epochs=1, lr=None, loss_func=nll):
        if lr: self.opt.lr = lr
        for epoch in range(epochs):
            for x,y in train_dl:
                if torch.cuda.is_available(): x,y=x.cuda(), y.cuda()
                    
                
                loss=nll(self.model(x),y)
                loss.backward()
                self.opt.step()
                self.opt.zero_grad()
            
            
            #validation accuracy calculation
            acc=0.
            i=0
            for x,y in valid_dl:
                if torch.cuda.is_available(): x,y=x.cuda(), y.cuda()
                acc+=accuracy(self.model(x),y)
                i+=1
            print(f"epoch{epoch+1}: validation accuracy: {acc/i}")
    
    def predict(self,x): return torch.argmax(self.model(x),dim=1)

# %%
model = get_cnn_model(num_classes=10)
opt=optimizer(model.parameters())
learn = Learner(train_dl,valid_dl, model=model, optimizer=opt)
learn.fit(10)

# %% [markdown]
# More Complex Networks
#
# Complex dataset
#
# COmplex Neural Networks

# %% [markdown]
# Cat vs Dog Images

# %%
# !pip install jmd_imagescraper >./tmp

# %%
from jmd_imagescraper.core import *
from pathlib import Path


root = Path().cwd()/"images"
duckduckgo_search(root,"cat", "cat", max_results=200)
duckduckgo_search(root,"dog","dog",max_results=200)
# Out:
# Duckduckgo search: cat
# Downloading results into /content/images/cat
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:18<00:00 Images downloaded]
#     </div>
# Duckduckgo search: dog
# Downloading results into /content/images/dog
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:20<00:00 Images downloaded]
#     </div>
# [PosixPath('/content/images/dog/001_e0f68140.jpg'),
#  PosixPath('/content/images/dog/002_0b5f7111.jpg'),
#  PosixPath('/content/images/dog/003_11978de8.jpg'),
#  PosixPath('/content/images/dog/004_85590eea.jpg'),
#  PosixPath('/content/images/dog/005_31af9c1d.jpg'),
#  PosixPath('/content/images/dog/006_927fb252.jpg'),
#  PosixPath('/content/images/dog/007_9acf6f88.jpg'),
#  PosixPath('/content/images/dog/008_01241e54.jpg'),
#  PosixPath('/content/images/dog/009_3a352698.jpg'),
#  PosixPath('/content/images/dog/010_48d7ea9f.jpg'),
#  PosixPath('/content/images/dog/011_354b8f24.jpg'),
#  PosixPath('/content/images/dog/012_be1239ba.jpg'),
#  PosixPath('/content/images/dog/013_77da8369.jpg'),
#  PosixPath('/content/images/dog/014_33ec9451.jpg'),
#  PosixPath('/content/images/dog/015_79a9f6e7.jpg'),
#  PosixPath('/content/images/dog/016_c659d23b.jpg'),
#  PosixPath('/content/images/dog/017_eb4405f2.jpg'),
#  PosixPath('/content/images/dog/018_7b54753f.jpg'),
#  PosixPath('/content/images/dog/019_8ee8da98.jpg'),
#  PosixPath('/content/images/dog/020_79cc7906.jpg'),
#  PosixPath('/content/images/dog/021_94675d03.jpg'),
#  PosixPath('/content/images/dog/022_1b34e2ce.jpg'),
#  PosixPath('/content/images/dog/023_e1bf75d3.jpg'),
#  PosixPath('/content/images/dog/024_2db881a8.jpg'),
#  PosixPath('/content/images/dog/025_01aeab14.jpg'),
#  PosixPath('/content/images/dog/026_f17f4b45.jpg'),
#  PosixPath('/content/images/dog/027_8b2404e1.jpg'),
#  PosixPath('/content/images/dog/028_0097e9b6.jpg'),
#  PosixPath('/content/images/dog/029_3c51fcbf.jpg'),
#  PosixPath('/content/images/dog/030_ec05e700.jpg'),
#  PosixPath('/content/images/dog/031_697bba03.jpg'),
#  PosixPath('/content/images/dog/032_8b4312c1.jpg'),
#  PosixPath('/content/images/dog/033_bbb310e5.jpg'),
#  PosixPath('/content/images/dog/034_c05770a8.jpg'),
#  PosixPath('/content/images/dog/035_82643d6a.jpg'),
#  PosixPath('/content/images/dog/036_05adc4ad.jpg'),
#  PosixPath('/content/images/dog/037_5f397f10.jpg'),
#  PosixPath('/content/images/dog/038_748f25be.jpg'),
#  PosixPath('/content/images/dog/039_651d62c2.jpg'),
#  PosixPath('/content/images/dog/040_74a79f57.jpg'),
#  PosixPath('/content/images/dog/041_cfad6e6b.jpg'),
#  PosixPath('/content/images/dog/042_30b39d87.jpg'),
#  PosixPath('/content/images/dog/043_658d8e00.jpg'),
#  PosixPath('/content/images/dog/044_800a6ec0.jpg'),
#  PosixPath('/content/images/dog/045_575146c0.jpg'),
#  PosixPath('/content/images/dog/046_dd29a67a.jpg'),
#  PosixPath('/content/images/dog/047_7dd3d692.jpg'),
#  PosixPath('/content/images/dog/048_67bb12cb.jpg'),
#  PosixPath('/content/images/dog/049_2b8d83e3.jpg'),
#  PosixPath('/content/images/dog/050_c5c08a2f.jpg'),
#  PosixPath('/content/images/dog/051_debfe33b.jpg'),
#  PosixPath('/content/images/dog/052_3733c1f1.jpg'),
#  PosixPath('/content/images/dog/053_f592c94c.jpg'),
#  PosixPath('/content/images/dog/054_46d42832.jpg'),
#  PosixPath('/content/images/dog/055_864e1394.jpg'),
#  PosixPath('/content/images/dog/056_cd7fe710.jpg'),
#  PosixPath('/content/images/dog/057_51f97f3b.jpg'),
#  PosixPath('/content/images/dog/058_6e651f27.jpg'),
#  PosixPath('/content/images/dog/059_dc8a4dee.jpg'),
#  PosixPath('/content/images/dog/060_5d6fb4f3.jpg'),
#  PosixPath('/content/images/dog/061_f56fc492.jpg'),
#  PosixPath('/content/images/dog/062_d35d98b6.jpg'),
#  PosixPath('/content/images/dog/063_18b1e686.jpg'),
#  PosixPath('/content/images/dog/064_0e852cd0.jpg'),
#  PosixPath('/content/images/dog/065_6f498c61.jpg'),
#  PosixPath('/content/images/dog/066_b9200b30.jpg'),
#  PosixPath('/content/images/dog/067_690c1c3d.jpg'),
#  PosixPath('/content/images/dog/068_a81bc3ff.jpg'),
#  PosixPath('/content/images/dog/069_e26a8b86.jpg'),
#  PosixPath('/content/images/dog/070_655d54b6.jpg'),
#  PosixPath('/content/images/dog/071_52f02f7e.jpg'),
#  PosixPath('/content/images/dog/072_de65c9a7.jpg'),
#  PosixPath('/content/images/dog/073_f4c0c4fb.jpg'),
#  PosixPath('/content/images/dog/074_4b2654d7.jpg'),
#  PosixPath('/content/images/dog/075_94392d8b.jpg'),
#  PosixPath('/content/images/dog/076_15e4dc4d.jpg'),
#  PosixPath('/content/images/dog/077_143478b0.jpg'),
#  PosixPath('/content/images/dog/078_24e0b5b1.jpg'),
#  PosixPath('/content/images/dog/079_c42d9f99.jpg'),
#  PosixPath('/content/images/dog/080_b72fa9d9.jpg'),
#  PosixPath('/content/images/dog/081_024ab968.jpg'),
#  PosixPath('/content/images/dog/082_b1c94125.jpg'),
#  PosixPath('/content/images/dog/083_3a386c0a.jpg'),
#  PosixPath('/content/images/dog/084_35d652db.jpg'),
#  PosixPath('/content/images/dog/085_f194ae00.jpg'),
#  PosixPath('/content/images/dog/086_f69ae285.jpg'),
#  PosixPath('/content/images/dog/087_8c68597d.jpg'),
#  PosixPath('/content/images/dog/088_d08d5c47.jpg'),
#  PosixPath('/content/images/dog/089_fde16ce1.jpg'),
#  PosixPath('/content/images/dog/090_48b13955.jpg'),
#  PosixPath('/content/images/dog/091_98696456.jpg'),
#  PosixPath('/content/images/dog/092_6feb7f7b.jpg'),
#  PosixPath('/content/images/dog/093_161342de.jpg'),
#  PosixPath('/content/images/dog/094_085a8c99.jpg'),
#  PosixPath('/content/images/dog/095_ad0b231b.jpg'),
#  PosixPath('/content/images/dog/096_8bb6dfd3.jpg'),
#  PosixPath('/content/images/dog/097_8eb2bb76.jpg'),
#  PosixPath('/content/images/dog/098_bab5e418.jpg'),
#  PosixPath('/content/images/dog/099_291f06fd.jpg'),
#  PosixPath('/content/images/dog/100_dd78bfa8.jpg'),
#  PosixPath('/content/images/dog/101_4aaa8566.jpg'),
#  PosixPath('/content/images/dog/102_b2392a6f.jpg'),
#  PosixPath('/content/images/dog/103_1666b1a9.jpg'),
#  PosixPath('/content/images/dog/104_8a2d4242.jpg'),
#  PosixPath('/content/images/dog/105_a96d20d7.jpg'),
#  PosixPath('/content/images/dog/106_f11391fb.jpg'),
#  PosixPath('/content/images/dog/107_5c4ee087.jpg'),
#  PosixPath('/content/images/dog/108_4abf8a29.jpg'),
#  PosixPath('/content/images/dog/109_8f6853e6.jpg'),
#  PosixPath('/content/images/dog/110_95558c5a.jpg'),
#  PosixPath('/content/images/dog/111_7afce41a.jpg'),
#  PosixPath('/content/images/dog/112_aa47f1c1.jpg'),
#  PosixPath('/content/images/dog/113_6a869259.jpg'),
#  PosixPath('/content/images/dog/114_f6e2e97c.jpg'),
#  PosixPath('/content/images/dog/115_e14f32bf.jpg'),
#  PosixPath('/content/images/dog/116_af8a17f3.jpg'),
#  PosixPath('/content/images/dog/117_3b292b9c.jpg'),
#  PosixPath('/content/images/dog/118_8b61fd2f.jpg'),
#  PosixPath('/content/images/dog/119_9a09856f.jpg'),
#  PosixPath('/content/images/dog/120_7d2ad61e.jpg'),
#  PosixPath('/content/images/dog/121_f90bc231.jpg'),
#  PosixPath('/content/images/dog/122_dbd88fa5.jpg'),
#  PosixPath('/content/images/dog/123_b14e9344.jpg'),
#  PosixPath('/content/images/dog/124_99e7370b.jpg'),
#  PosixPath('/content/images/dog/125_383457f1.jpg'),
#  PosixPath('/content/images/dog/126_d0345a06.jpg'),
#  PosixPath('/content/images/dog/127_67cabe63.jpg'),
#  PosixPath('/content/images/dog/128_2f3c6208.jpg'),
#  PosixPath('/content/images/dog/129_c3b3a915.jpg'),
#  PosixPath('/content/images/dog/130_8baf54c5.jpg'),
#  PosixPath('/content/images/dog/131_c0c2e351.jpg'),
#  PosixPath('/content/images/dog/132_c9b22fe6.jpg'),
#  PosixPath('/content/images/dog/133_b843b991.jpg'),
#  PosixPath('/content/images/dog/134_b315258a.jpg'),
#  PosixPath('/content/images/dog/135_8f4900fd.jpg'),
#  PosixPath('/content/images/dog/136_f2683cd4.jpg'),
#  PosixPath('/content/images/dog/137_c6b162d4.jpg'),
#  PosixPath('/content/images/dog/138_f956bfa9.jpg'),
#  PosixPath('/content/images/dog/139_8e3e0c6a.jpg'),
#  PosixPath('/content/images/dog/140_71442a11.jpg'),
#  PosixPath('/content/images/dog/141_3a6688ef.jpg'),
#  PosixPath('/content/images/dog/142_c61d93a6.jpg'),
#  PosixPath('/content/images/dog/143_2dbd9bb6.jpg'),
#  PosixPath('/content/images/dog/144_b9a9fd28.jpg'),
#  PosixPath('/content/images/dog/145_01527f53.jpg'),
#  PosixPath('/content/images/dog/146_555db6d1.jpg'),
#  PosixPath('/content/images/dog/147_819b46dd.jpg'),
#  PosixPath('/content/images/dog/148_09f0b560.jpg'),
#  PosixPath('/content/images/dog/149_84f0c646.jpg'),
#  PosixPath('/content/images/dog/150_0e85251c.jpg'),
#  PosixPath('/content/images/dog/151_bfc8e9e4.jpg'),
#  PosixPath('/content/images/dog/152_7cbd0482.jpg'),
#  PosixPath('/content/images/dog/153_a458027a.jpg'),
#  PosixPath('/content/images/dog/154_6a23c98b.jpg'),
#  PosixPath('/content/images/dog/155_d3b96a47.jpg'),
#  PosixPath('/content/images/dog/156_b3a449af.jpg'),
#  PosixPath('/content/images/dog/157_40ff7bf0.jpg'),
#  PosixPath('/content/images/dog/158_0f22e2af.jpg'),
#  PosixPath('/content/images/dog/159_da8fe50b.jpg'),
#  PosixPath('/content/images/dog/160_18921300.jpg'),
#  PosixPath('/content/images/dog/161_5cd5f0b2.jpg'),
#  PosixPath('/content/images/dog/162_e18bffa4.jpg'),
#  PosixPath('/content/images/dog/163_ea9514a0.jpg'),
#  PosixPath('/content/images/dog/164_4048bef1.jpg'),
#  PosixPath('/content/images/dog/165_17ccf377.jpg'),
#  PosixPath('/content/images/dog/166_9ea1d88f.jpg'),
#  PosixPath('/content/images/dog/167_2b078a00.jpg'),
#  PosixPath('/content/images/dog/168_6915be82.jpg'),
#  PosixPath('/content/images/dog/169_0abc2813.jpg'),
#  PosixPath('/content/images/dog/170_44fc7c5c.jpg'),
#  PosixPath('/content/images/dog/171_065a40f0.jpg'),
#  PosixPath('/content/images/dog/172_5d94ea78.jpg'),
#  PosixPath('/content/images/dog/173_951a8d61.jpg'),
#  PosixPath('/content/images/dog/174_c65932d7.jpg'),
#  PosixPath('/content/images/dog/175_92fbd615.jpg'),
#  PosixPath('/content/images/dog/176_44a047d4.jpg'),
#  PosixPath('/content/images/dog/177_a06f5396.jpg'),
#  PosixPath('/content/images/dog/178_3f523130.jpg'),
#  PosixPath('/content/images/dog/179_e3ecdf45.jpg'),
#  PosixPath('/content/images/dog/180_d8f214cf.jpg'),
#  PosixPath('/content/images/dog/181_2047307b.jpg'),
#  PosixPath('/content/images/dog/182_e35cd825.jpg'),
#  PosixPath('/content/images/dog/183_24f904d7.jpg'),
#  PosixPath('/content/images/dog/184_90a067b3.jpg'),
#  PosixPath('/content/images/dog/185_bdce7772.jpg'),
#  PosixPath('/content/images/dog/186_b38c35f4.jpg'),
#  PosixPath('/content/images/dog/187_a3a8b55b.jpg'),
#  PosixPath('/content/images/dog/188_8ab0ff1d.jpg'),
#  PosixPath('/content/images/dog/189_6a0bcfda.jpg'),
#  PosixPath('/content/images/dog/190_b728bbc2.jpg'),
#  PosixPath('/content/images/dog/191_cf4af205.jpg'),
#  PosixPath('/content/images/dog/192_3a041969.jpg'),
#  PosixPath('/content/images/dog/193_29d1b77d.jpg'),
#  PosixPath('/content/images/dog/194_908656f7.jpg'),
#  PosixPath('/content/images/dog/195_60901b20.jpg'),
#  PosixPath('/content/images/dog/196_9f0695b8.jpg'),
#  PosixPath('/content/images/dog/197_def9969b.jpg'),
#  PosixPath('/content/images/dog/198_b35fc73c.jpg'),
#  PosixPath('/content/images/dog/199_eb2102ae.jpg'),
#  PosixPath('/content/images/dog/200_075927c4.jpg')]

# %%
# !cd images/cat && ls
# Out:
# 001_99bf44c5.jpg  051_1ac5535f.jpg  101_20f176f1.jpg  151_a0615e4a.jpg
# 002_b430063d.jpg  052_c192156f.jpg  102_830fad30.jpg  152_6d0dd3b2.jpg
# 003_840a9a33.jpg  053_9a64280f.jpg  103_70c9955f.jpg  153_240899a8.jpg
# 004_e4f3dff7.jpg  054_805a784d.jpg  104_711c7cc5.jpg  154_6ed521bf.jpg
# 005_4c3cd5eb.jpg  055_b21e7707.jpg  105_0e9d20ea.jpg  155_81ebab31.jpg
# 006_be547fb6.jpg  056_1252efcf.jpg  106_5c8f6f02.jpg  156_8ae42daf.jpg
# 007_c066efb6.jpg  057_a8d867ec.jpg  107_c58f3751.jpg  157_8c732c79.jpg
# 008_7a6098f2.jpg  058_ffa347e6.jpg  108_16af297e.jpg  158_c607f2f7.jpg
# 009_68559625.jpg  059_d6195447.jpg  109_25581a62.jpg  159_256d19d6.jpg
# 010_ac24e6da.jpg  060_7292b39d.jpg  110_a235eaf9.jpg  160_be4cb193.jpg
# 011_c6c433c2.jpg  061_5788dde4.jpg  111_478f01b9.jpg  161_7ffd9196.jpg
# 012_9816c045.jpg  062_98a3b032.jpg  112_72e76f95.jpg  162_2b8fb6d1.jpg
# 013_00a83cc0.jpg  063_d3b92114.jpg  113_5b8803f0.jpg  163_b548f298.jpg
# 014_0799e4bd.jpg  064_03a53d50.jpg  114_9ce60873.jpg  164_50119cfe.jpg
# 015_f8cde632.jpg  065_775f7be7.jpg  115_8cd021bd.jpg  165_abcb5de5.jpg
# 016_b27b5333.jpg  066_8286b9fd.jpg  116_4b6f40be.jpg  166_88bff4fd.jpg
# 017_1d0d6544.jpg  067_55333ef1.jpg  117_18140665.jpg  167_08120e3a.jpg
# 018_31326e7d.jpg  068_b4c0b593.jpg  118_982fc171.jpg  168_4e38d619.jpg
# 019_3d7d7721.jpg  069_bc02d94c.jpg  119_e089a915.jpg  169_281b8123.jpg
# 020_311fb478.jpg  070_eeb628e8.jpg  120_6dd723dd.jpg  170_5476de5e.jpg
# 021_ec20e585.jpg  071_ebf8b523.jpg  121_9ae60bb1.jpg  171_c8ace453.jpg
# 022_8fdcbc02.jpg  072_7398040d.jpg  122_4dcc22be.jpg  172_1ccee2b7.jpg
# 023_5568cf36.jpg  073_2c7df878.jpg  123_c4a83d7f.jpg  173_df19dd7a.jpg
# 024_1e49f078.jpg  074_5181ebbe.jpg  124_1ae04589.jpg  174_b6213add.jpg
# 025_d538c2a1.jpg  075_a7ee2902.jpg  125_cc7e70a9.jpg  175_4e5bfc4f.jpg
# 026_74a2dcf9.jpg  076_15947bb9.jpg  126_90f516e2.jpg  176_573951e7.jpg
# 027_b759eacf.jpg  077_d941f0d5.jpg  127_1c765cde.jpg  177_09d792c7.jpg
# 028_6929fd3e.jpg  078_fde67bc8.jpg  128_32dd1444.jpg  178_58d787a4.jpg
# 029_ed2cc7e4.jpg  079_8adfe766.jpg  129_2f39d1e2.jpg  179_734ece37.jpg
# 030_f19125d5.jpg  080_1b546386.jpg  130_d1b0de04.jpg  180_4c938069.jpg
# 031_70fc8560.jpg  081_d80033d7.jpg  131_85247e52.jpg  181_f5f5e117.jpg
# 032_601abcd0.jpg  082_d81ba0c2.jpg  132_d530e4c3.jpg  182_84ca123b.jpg
# 033_99446308.jpg  083_c6f07923.jpg  133_f0f64e83.jpg  183_214587e5.jpg
# 034_1667dd09.jpg  084_3b2bf081.jpg  134_147db53f.jpg  184_d6d10071.jpg
# 035_3de904a5.jpg  085_091f4b59.jpg  135_8da6e591.jpg  185_d8ef968b.jpg
# 036_e660519c.jpg  086_c880bb59.jpg  136_d4c055b6.jpg  186_70cf7036.jpg
# 037_58fd6caa.jpg  087_2b89efc3.jpg  137_6316e7b7.jpg  187_4aa0a87c.jpg
# 038_2fa54eba.jpg  088_18a641d5.jpg  138_6fd711b3.jpg  188_d50d6d1d.jpg
# 039_9f73ed61.jpg  089_439405b0.jpg  139_d19e2840.jpg  189_d948c7c8.jpg
# 040_3e1d49d7.jpg  090_3ae65f0d.jpg  140_b43ca044.jpg  190_17d99b13.jpg
# 041_13e54091.jpg  091_b977735e.jpg  141_664d7e16.jpg  191_ae15b176.jpg
# 042_ce8f9979.jpg  092_4967d340.jpg  142_97f2bbaf.jpg  192_748d81a4.jpg
# 043_44b6b482.jpg  093_38fbf9ca.jpg  143_68f8897b.jpg  193_50116413.jpg
# 044_1d1aa8c3.jpg  094_bfb70ab4.jpg  144_86e38b14.jpg  194_24f8c697.jpg
# 045_0561f3ad.jpg  095_631da545.jpg  145_59c91dc0.jpg  195_f730fb42.jpg
# 046_c60d54e8.jpg  096_08b2166d.jpg  146_f5d22961.jpg  196_56c6d71c.jpg
# 047_de734e68.jpg  097_53e97277.jpg  147_a743a141.jpg  197_431febe0.jpg
# 048_4f5d7203.jpg  098_db571ffe.jpg  148_6b1dee15.jpg  198_2de1b449.jpg
# 049_3fc19ef8.jpg  099_1f7192c7.jpg  149_2e3af836.jpg  199_172cc8ea.jpg
# 050_2a197a40.jpg  100_afa06ee4.jpg  150_2759c9b1.jpg  200_e32d212f.jpg

# %%
from jmd_imagescraper.imagecleaner import *
display_image_cleaner(root)
# Out:
# HBox(children=(Button(description='|<<', layout=Layout(width='60px'), style=ButtonStyle()), Button(description…
# HTML(value='<h2>No images left to display in this folder.</h2>', layout=Layout(visibility='hidden'))
# GridBox(children=(VBox(children=(Image(value=b'', layout="Layout(width='150px')"), Button(description='Delete'…

# %%
from torch.utils.data import DataLoader, Dataset, random_split
import os
from PIL import Image

class CatvsDogDataset(Dataset):
    def __init__(self,root='images',transforms=None):
        self.classes = {v:i for i,v in enumerate(os.listdir(root))}
        self.transforms = [lambda x: x] if not transforms else transforms

        self.x=[]
        self.y=[]

        for p,d,f in os.walk(root):
            for file in f:
                if file.endswith('.jpg'):
                    self.x.append(Image.open(Path(p)/file))
                    self.y.append(self.classes[Path(p).stem])


    def __len__(self): return len(self.x)
    def __getitem__(self,i): 
        return (self.apply_tfms(self.x[i],self.transforms),self.y[i])
    


    def apply_tfms(self,x,tfm_list):
        for tfm in tfm_list: x= tfm(x)
        return x

# %%
data = CatvsDogDataset(transforms = [torchvision.transforms.ToTensor(),
                                     torchvision.transforms.CenterCrop(size=300)])

# %%
def split_ds_by_pct(dataset, pct=0.8):
    assert 0.<pct<1., "pct should be (a floating point) between 0 and 1"
    return random_split(dataset,[int(pct*len(dataset)), (len(dataset) - int(pct*len(dataset)) )])

train_ds,val_ds = split_ds_by_pct(data)
len(train_ds), len(val_ds)

# %%
train_dl = DataLoader(train_ds, batch_size=64, shuffle=True)
valid_dl = DataLoader(val_ds, batch_size=2*64, shuffle=False)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device

# %%
x,y = next(iter(train_dl))
x.shape

# %% [markdown]
# Advanced model: resnet18

# %%
resnet18 = torchvision.models.resnet18(pretrained=True)
resnet18 = resnet18.cuda() if device else resnet18
resnet18

# %%
resnet18.conv1

# %%
resnet18.fc

# %%
resnet18.fc = nn.Linear(512, 2) #because we are doing a 2 label classification

# %%
def get_resnet(classes =2,pretrained=True, device='cuda:0'):
    resnet18 = torchvision.models.resnet18(pretrained=True)
    resnet18 = resnet18.cuda() if device=='cuda' else resnet18

    resnet18.fc = nn.Linear(512, classes)

    # resnet18.fc = resnet18.fc.cuda() if device=='cuda' else resnet18.fc

    return resnet18.cuda() if torch.cuda.is_available() else resnet18

# %%
x,_ = next(iter(train_dl))
x=x.cuda()
resnet18(x).shape

# %%
def preprocess(x):
    x=torch.nn.functional.normalize(x)
    return x

# %%
class Learner():
  def __init__(self,train_dl,valid_dl,model,optimizer=None): #remove default value of model
    self.train_dl=train_dl
    self.valid_dl=valid_dl
    self.model=model
    self.opt=optimizer(self.model.parameters()) if not optimizer else optimizer

  def fit(self,epochs=1, bs=64,lr=None,loss_func=nll):
    lr=self.opt.lr if not lr else lr
    for epoch in range(epochs):
      for x,y in train_dl:
        x,y=x.cuda(),y.cuda()
        x=preprocess(x)

        loss = nll(self.model(x),y)
        loss.backward()
        self.opt.step()
        self.opt.zero_grad()
      acc=0.
      i=0

      for x,y in list(valid_dl):
        x,y = x.cuda(),y.cuda()
        x=preprocess(x)         # mnist_preprocess --> process
        acc+=accuracy(self.model(x),y)
        i+=1
      print(f"epoch {epoch+1}: validation accuracy: {acc/i}")
  
  def predict(self,x): return torch.argmax(self.model(x),dim=1)



model=get_resnet(classes =2,device='cuda')
# model=get_cnn_model(num_classes=2)
opt=optimizer(model.parameters())
learn = Learner(train_dl, valid_dl, model, optimizer = opt)

# %%
learn.fit(10,1e-1)
